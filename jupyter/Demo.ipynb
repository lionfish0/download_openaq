# %%
from download_openaq import download
import numpy as np

# %%
data = download('US Diplomatic Post: Kampala',verbose=True)
# Out:
# Trying cache
# Loaded 2170 records from cache.
# Loading API page 1
# Combining 2170 cached records with 1000 API records
# Total data set contains 2170 records

# %%
data
# Out:
#                         city  coordinates.latitude  coordinates.longitude  \
# date.local
# 2018-05-14 14:00:00  Kampala              0.300225              32.591553
# 2018-05-14 13:00:00  Kampala              0.300225              32.591553
# 2018-05-14 12:00:00  Kampala              0.300225              32.591553
# 2018-05-14 11:00:00  Kampala              0.300225              32.591553
# 2018-05-14 10:00:00  Kampala              0.300225              32.591553
# 2018-05-14 09:00:00  Kampala              0.300225              32.591553
# 2018-05-14 08:00:00  Kampala              0.300225              32.591553
# 2018-05-14 07:00:00  Kampala              0.300225              32.591553
# 2018-05-14 06:00:00  Kampala              0.300225              32.591553
# 2018-05-14 05:00:00  Kampala              0.300225              32.591553
# 2018-05-14 04:00:00  Kampala              0.300225              32.591553
# ...
